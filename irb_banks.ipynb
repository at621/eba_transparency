# %% [markdown]
# ### Identify the IRB Banks in the Transparency Exercise
#
# **The calculations may contain errors or misinterpretations of the EBA Transparency datasets.**
#
#
# ## Introduction
#
# This notebook explores the datasets provided by the European Banking Authority (EBA) under their EU-wide Transparency Exercise, accessible [here](https://www.eba.europa.eu/risk-analysis-and-data/eu-wide-transparency-exercise). These datasets offer a comprehensive view of the banking sector's assets and risks, which is invaluable for financial analysis and regulatory assessment.
#
# ### Nations.
# - **Ensure Data Integrity**: Although these datasets are generally user-friendly, they require additional checks to validate data integrity and reliability. You should compare a sample of your intermediary results with the results presented by the EBA's interactive tool, specifically the visualizations found [here](https://tools.eba.europa.eu/interactive-tools/2023/powerbi/837203/tr23_visualisation_page5.html), to confirm consistency and understand any discrepancies.
# - **Download the credit risk datasets from here**: https://www.eba.europa.eu/assets/TE2023/Full_database/837203/tr_cre.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Settings
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# #### A. Create base table

# %%
# Import mappning tables
exposures = pd.read_excel('kala_eba_tr.xlsx', sheet_name='Exposures')
portfolio = pd.read_excel('kala_eba_tr.xlsx', sheet_name='Portfolio')
country = pd.read_excel('kala_eba_tr.xlsx', sheet_name='Country')
status = pd.read_excel('kala_eba_tr.xlsx', sheet_name='Status')
perf_status = pd.read_excel('kala_eba_tr.xlsx', sheet_name='Perf_Status')
institutions = pd.read_excel('kala_eba_tr.xlsx', sheet_name='List of institutions')

# import core dataset
df = pd.read_csv('tr_cre.csv', low_memory=False)

# %%
# Create final dataset
result = pd.merge(df, exposures, on='Exposure', how='left')
result = pd.merge(result, portfolio, on='Portfolio', how='left')
result = pd.merge(result, country, on='Country', how='left')
result = pd.merge(result, status, on='Status', how='left')
result = pd.merge(result, perf_status, on='Perf_Status', how='left')
result = pd.merge(result, institutions, on='LEI_Code', how='left')

result.head(2)
# Out:
#                LEI_Code NSA  Period     Item  \
# 0  0W2PZJM8XOY22M4GG883  DE  202209  2320502
# 1  0W2PZJM8XOY22M4GG883  DE  202209  2320502
#
#                                                Label  Portfolio  Country  \
# 0  Original Exposure - by exposure class (SA_and_...          2        0
# 1  Original Exposure - by exposure class (SA_and_...          2        0
#
#    Country_rank  Exposure  Status  Perf_Status  NACE_codes    Amount Footnote  \
# 0             0       103       0            0           0    419.98      NaN
# 1             0       203       0            0           0 16,941.37      NaN
#
#    Row  Column              Sheet                        exposure_label  \
# 0   10       4  Credit Risk_IRB_a  Central governments or central banks
# 1   11       4  Credit Risk_IRB_a                          Institutions
#
#   portfolio_label          country_label ISO_code            status_label  \
# 0             IRB  Total / No breakdown        00  No breakdown by status
# 1             IRB  Total / No breakdown        00  No breakdown by status
#
#              perf_status_label institution_country Desc_country  \
# 0  No breakdown by Perf_status                  DE      Germany
# 1  No breakdown by Perf_status                  DE      Germany
#
#                              Name      Finrep Fin_year_end
# 0  DekaBank Deutsche Girozentrale  Yes - IFRS        31/12
# 1  DekaBank Deutsche Girozentrale  Yes - IFRS        31/12

# %%
# Check the number of observations per row
idx_1 = result['Label'] == 'Exposure value - by exposure class (SA_and_IRB)'
idx_2 = result['Period'] == 202306
idx_3 = result['Desc_country'] == result['country_label']

# Sanity checking, only one row per groupby is expected
test = (result[idx_1 & idx_2 & idx_3]
        .groupby(['Desc_country', 'exposure_label', 'portfolio_label', 'Name'])
        .agg({'Amount': ['sum', 'count']}))
assert test[test.columns[-1]].max() == 1, 'Check your filtering criteria'

# %%
# Create base table
idx_1 = result['Label'] == 'Exposure value - by exposure class (SA_and_IRB)'
idx_2 = result['Period'] == 202306
idx_3 = result['Desc_country'] == result['country_label']

pivot_df = pd.pivot_table(result[idx_1 & idx_2 & idx_3], 
                          values='Amount', 
                          index=['exposure_label', 'portfolio_label'], 
                          columns=['Name'], 
                          aggfunc="sum", 
                          margins=True,
                          fill_value=0).reset_index()

# %% [markdown]
# #### B. Calculate RWA and exposure values

# %%
# Calculate Exposure values
idx_1 = result['Desc_country'] == result['country_label']
idx_2 = result['Label'].isin(['Exposure value - by exposure class (SA_and_IRB)', 
                              'Risk exposure amount - by exposure class (SA_and_IRB)', 
                              'Risk Exposure amount - of which_DEFAULTED  - by exposure class (IRB)'])
idx_3 = result['Period'] == 202306

pivot_df2 = pd.pivot_table(result[idx_1 & idx_2 & idx_3], 
                      values='Amount', 
                      index=['exposure_label', 'portfolio_label', 'Name', 'country_label'], 
                      columns=['Label'], 
                      aggfunc="sum", 
                      margins=False,
                      fill_value=0).reset_index()


# Create a rank based on the summed 'Exposure value', sorted by size
grouped = pivot_df2.groupby('exposure_label')['Exposure value - by exposure class (SA_and_IRB)'].sum()
rank = grouped.sort_values(ascending=False).rank(method='dense', ascending=False).astype(int)

# Map the ranks back to the original DataFrame
pivot_df2['exposure_type_size'] = pivot_df2['exposure_label'].map(rank)

pivot_df2 = pivot_df2.rename(columns={
    'Exposure value - by exposure class (SA_and_IRB)': 'exposure_value',
    'Risk exposure amount - by exposure class (SA_and_IRB)': 'risk_exposure',
    'Risk Exposure amount - of which_DEFAULTED  - by exposure class (IRB)': 'defaulted_risk_exposure',
})

pivot_df2['risk_weight'] = (pivot_df2['risk_exposure'] / pivot_df2['exposure_value']) * 100

final_df = pivot_df2.sort_values(by='exposure_type_size', ascending=True).reset_index()
final_df.to_excel('transprency_irb_v2.xlsx')

# %% [markdown]
# #### C. Summary table of IRB banks

# %%
# Show RWA for segments with at least 1bn EUR per bank / exposure
idx_1 = pivot_df2['exposure_label'].isin(['Retail', 'Corporates'])
idx_2 = pivot_df2['portfolio_label'] == 'IRB'
idx_3 = pivot_df2['exposure_value'] > 1_000

df3 = pivot_df2[idx_2 & idx_3]

final_results = (df3.pivot_table(index='Name', 
                                 columns='exposure_label', 
                                 values='exposure_value', 
                                 aggfunc='sum', 
                                 margins=True)
                 .fillna(0)
                 .sort_values(by='All', ascending=False))
final_results
# Out:
# exposure_label                                      Central governments or central banks  \
# Name
# All                                                                         1,183,686.23
# Groupe Crédit Agricole                                                        216,093.61
# Groupe BPCE                                                                   160,561.55
# Confédération Nationale du Crédit Mutuel                                            0.00
# BNP Paribas                                                                   208,468.06
# Société générale S.A.                                                         162,277.10
# Coöperatieve Rabobank U.A.                                                     96,187.36
# Intesa Sanpaolo S.p.A.                                                              0.00
# ABN AMRO Bank N.V.                                      1,649.65   160,710.38
# Bayerische Landesbank                                  15,988.30    25,357.02
# ING Groep N.V.                                          4,536.79   125,288.79
# COMMERZBANK Aktiengesellschaft                          6,724.89   136,318.21
# DZ BANK AG Deutsche Zentral-Genossenschaftsbank...      7,980.21    92,251.73
# Nykredit Realkredit A/S                                     0.00   112,140.16
# Svenska Handelsbanken - gruppen                         2,095.33    83,816.02
# Banco Santander, S.A.                                   7,310.73    95,388.90
# Landesbank Baden-Württemberg                           10,202.93         0.00
# Banco Bilbao Vizcaya Argentaria, S.A.                  23,647.72    87,405.48
# Swedbank - Grupp                                        2,190.07    94,482.37
# Danske Bank A/S                                         2,027.64    67,665.12
# DNB BANK ASA                                                0.00    85,216.06
# Skandinaviska Enskilda Banken - gruppen                 6,871.57    52,481.28
# KBC Groep                                               5,267.90    65,963.25
# Belfius Bank                                           17,808.65    55,183.40
# UNICREDIT, SOCIETA' PER AZIONI                          5,177.15    59,685.57
# Landesbank Hessen-Thüringen Girozentrale                3,217.53     6,314.30
# Erste Group Bank AG                                     2,278.86    48,044.81
# BANCO BPM SOCIETA' PER AZIONI                               0.00    43,796.88
# Banco de Sabadell, S.A.                                     0.00    41,709.38
# Nordea Bank Abp                                             0.00    43,163.98
# BPER Banca S.p.A.                                           0.00    40,725.40
# Jyske Bank A/S                                              0.00    29,206.23
# de Volksbank N.V.                                           0.00    50,226.04
# Norddeutsche Landesbank - Girozentrale -                3,256.77     2,881.50
# Crelan                                                      0.00    44,538.65
# SBAB Bank AB - Grupp                                        0.00    35,697.14
# HSBC Continental Europe                                 2,256.84    22,818.41
# Bankinter, S.A.                                             0.00    23,445.96
# Bank of Ireland Group plc                                   0.00    27,546.90
# Erwerbsgesellschaft der S-Finanzgruppe mbH & Co...          0.00    15,639.87
# Münchener Hypothekenbank eG                                 0.00    28,240.27
# SFIL S.A.                                              35,450.23         0.00
# Banco Comercial Português, SA                               0.00    22,819.89
# CREDITO EMILIANO HOLDING SOCIETA' PER AZIONI                0.00    14,216.22
# AIB Group plc                                               0.00    19,043.07
# Banque et Caisse d´Epargne de l´Etat, Luxembourg            0.00    21,113.16
# SPAREBANK 1 SR-BANK ASA                                     0.00    16,489.72
# BANCA POPOLARE DI SONDRIO SOCIETA' PER AZIONI               0.00     9,867.05
# SpareBank 1 SMN                                             0.00    15,380.19
# Mediobanca - Banca di Credito Finanziario S.p.A.            0.00    12,296.79
# Investeringsmaatschappij Argenta                            0.00    19,001.70
# LSF Nani Investments S.à r.l.                               0.00    10,633.93
# RCI Banque                                                  0.00    11,141.88
# Unicaja Banco, S.A.                                         0.00    19,137.11
# Banque Internationale à Luxembourg                          0.00     9,170.43
# BAWAG Group AG                                              0.00    10,417.01
# Raiffeisen Bank International AG                        1,816.92         0.00
# Hamburg Commercial Bank AG                                  0.00         0.00
# Deutsche Pfandbriefbank AG                                  0.00         0.00
# DekaBank Deutsche Girozentrale                          2,619.26         0.00
# Morgan Stanley Europe Holding SE                        1,383.61         0.00
# Atlantic Lux HoldCo S.à r.l.                                0.00         0.00
#
# exposure_label                                              All
# Name
# All                                                8,804,408.29
# Groupe Crédit Agricole                             1,020,034.95
# Groupe BPCE                                          800,852.41
# Confédération Nationale du Crédit Mutuel             577,743.18
# BNP Paribas                                          501,788.09
# Société générale S.A.                                449,428.93
# Coöperatieve Rabobank U.A.                           422,930.52
# Intesa Sanpaolo S.p.A.                               282,411.15
# DEUTSCHE BANK AKTIENGESELLSCHAFT                     268,509.60
# CaixaBank, S.A.                                      263,022.78
# ABN AMRO Bank N.V.                                   225,134.29
# Bayerische Landesbank                                218,323.96
# ING Groep N.V.                                       208,817.21
# COMMERZBANK Aktiengesellschaft                       201,750.31
# DZ BANK AG Deutsche Zentral-Genossenschaftsbank...   189,101.72
# Nykredit Realkredit A/S                              178,364.28
# Svenska Handelsbanken - gruppen                      177,456.87
# Banco Santander, S.A.                                170,130.44
# Landesbank Baden-Württemberg                         169,876.14
# Banco Bilbao Vizcaya Argentaria, S.A.                168,955.75
# Swedbank - Grupp                                     157,591.12
# Danske Bank A/S                                      140,641.66
# DNB BANK ASA                                         137,557.26
# Skandinaviska Enskilda Banken - gruppen              137,279.40
# KBC Groep                                            125,826.16
# Belfius Bank                                         125,539.27
# UNICREDIT, SOCIETA' PER AZIONI                       121,033.65
# Landesbank Hessen-Thüringen Girozentrale             116,581.38
# Erste Group Bank AG                                  107,540.32
# BANCO BPM SOCIETA' PER AZIONI                         86,718.43
# Banco de Sabadell, S.A.                               72,015.03
# Nordea Bank Abp                                       68,576.56
# BPER Banca S.p.A.                                     64,298.17
# Jyske Bank A/S                                        63,606.97
# de Volksbank N.V.                                     50,226.04
# Norddeutsche Landesbank - Girozentrale -              46,218.40
# Crelan                                                46,193.63
# SBAB Bank AB - Grupp                                  44,806.37
# HSBC Continental Europe                               44,067.89
# Bankinter, S.A.                                       39,411.26
# Bank of Ireland Group plc                             38,760.28
# Erwerbsgesellschaft der S-Finanzgruppe mbH & Co...    37,324.80
# Münchener Hypothekenbank eG                           36,303.46
# SFIL S.A.                                             35,450.23
# Banco Comercial Português, SA                         34,492.17
# CREDITO EMILIANO HOLDING SOCIETA' PER AZIONI          29,677.00
# AIB Group plc                                         28,769.97
# Banque et Caisse d´Epargne de l´Etat, Luxembourg      28,664.67
# SPAREBANK 1 SR-BANK ASA                               25,834.50
# BANCA POPOLARE DI SONDRIO SOCIETA' PER AZIONI         23,388.09
# SpareBank 1 SMN                                       21,547.66
# Mediobanca - Banca di Credito Finanziario S.p.A.      20,890.01
# Investeringsmaatschappij Argenta                      20,597.75
# LSF Nani Investments S.à r.l.                         19,866.63
# RCI Banque                                            19,576.34
# Unicaja Banco, S.A.                                   19,137.11
# Banque Internationale à Luxembourg                    13,537.42
# BAWAG Group AG                                        11,870.02
# Raiffeisen Bank International AG                      11,481.12
# Hamburg Commercial Bank AG                            11,111.07
# Deutsche Pfandbriefbank AG                            10,583.61
# DekaBank Deutsche Girozentrale                         9,324.05
# Morgan Stanley Europe Holding SE                       3,108.62
# Atlantic Lux HoldCo S.à r.l.                           2,750.18
